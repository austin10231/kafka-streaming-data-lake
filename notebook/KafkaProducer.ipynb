# %%
pip install kafka-python
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from kafka import KafkaConsumer, KafkaProducer
from time import sleep
from json import dumps
import json

# %%
producer = KafkaProducer(bootstrap_servers=['52.53.227.127:9092'],
                        value_serializer=lambda x:
                        dumps(x).encode('utf-8'))

# %%
producer.send('demo_test', value={'surname':'mutian'})

# %%
df = pd.read_csv('/Users/mr.tian/Desktop/indexProcessed.csv')

# %%
df.head()
# Out:
#   Index        Date         Open         High          Low        Close  \
# 0   HSI  1986-12-31  2568.300049  2568.300049  2568.300049  2568.300049
# 1   HSI  1987-01-02  2540.100098  2540.100098  2540.100098  2540.100098
# 2   HSI  1987-01-05  2552.399902  2552.399902  2552.399902  2552.399902
# 3   HSI  1987-01-06  2583.899902  2583.899902  2583.899902  2583.899902
# 4   HSI  1987-01-07  2607.100098  2607.100098  2607.100098  2607.100098
#
#      Adj Close  Volume    CloseUSD
# 0  2568.300049     0.0  333.879006
# 1  2540.100098     0.0  330.213013
# 2  2552.399902     0.0  331.811987
# 3  2583.899902     0.0  335.906987
# 4  2607.100098     0.0  338.923013

# %%
while True:
    dict_stock = df.sample(1).to_dict(orient='records')
    producer.send('demo_test', value=dict_stock)
    sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 4
#       2 dict_stock = df.sample(1).to_dict(orient='records')
#       3 producer.send('demo_test', value=dict_stock)
# ----> 4 sleep(1)
#
# KeyboardInterrupt:

# %%
producer.flush() #再次运行consumer就可以清空数据
